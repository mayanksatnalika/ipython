# %%
import tweepy
from pymongo import MongoClient
import json
import pandas 

#override tweepy.StreamListener to add logic to on_statu
#client = MongoClient()
#client = MongoClient('localhost', 27017)
#def on_connect(self):
#    print("You're connected to the streaming server.")
consumer_key = "POA1eXAkYisz3kBRdcmjeBcha"
consumer_secret = "Ol97n9dfJcSiHvxUmPfRoR7QcLBMzuM5MdOrG36dBuNyT2EzNw"
access_token = "354671169-ROmqMvVamNyggX9hqNzlpqhTgc6AkCOpT6bsjodA"
access_secret = "RqlakpclhdjQzijYhaSfqqK0Yhzv3AZe6RdQggdms8sYn"
 
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.secure = True
auth.set_access_token(access_token, access_secret)
 
api = tweepy.API(auth)
places = api.geo_search(query="India", granularity="country")
place_id = places[0].id

# %%
class MyStreamListener(tweepy.StreamListener):

    print('func called')
    
    
    
    def on_data(self, data):
        # Decode JSON
        client = MongoClient('localhost', 27017)
        db = client.newtweetsDB
        
        datajson = json.loads(data)
        db.cooltweets.insert(datajson)
        print("inserted")
        
     
        
myStreamListener = MyStreamListener()

myStream = tweepy.Stream(auth = api.auth, listener=myStreamListener)


#myStream.filter(track=['python'])


GEOBOX_WORLD = [-180,-90,180,90]

#format = [leftLimit   lowerLimit    rightLimit     upperLimit]
GEOBOX_GERMANY = [5.0770049095, 47.2982950435, 15.0403900146, 54.9039819757]

GEOBOX_INDIA = [71.1924, 8.0883,94.7278, 33.7782]

myStream.filter(locations=GEOBOX_INDIA)
# Out:
# func called
# /usr/local/lib/python2.7/dist-packages/ipykernel/__main__.py:13: DeprecationWarning: insert is deprecated. Use insert_one or insert_many instead.
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# inserted
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-20-7b3f93a9685a> in <module>()
#      31 GEOBOX_INDIA = [71.1924, 8.0883,94.7278, 33.7782]
#      32
# ---> 33 myStream.filter(locations=GEOBOX_INDIA)
#
# /usr/local/lib/python2.7/dist-packages/tweepy/streaming.pyc in filter(self, follow, track, async, locations, stall_warnings, languages, encoding, filter_level)
#     443         self.session.params = {'delimited': 'length'}
#     444         self.host = 'stream.twitter.com'
# --> 445         self._start(async)
#     446
#     447     def sitestream(self, follow, stall_warnings=False,
#
# /usr/local/lib/python2.7/dist-packages/tweepy/streaming.pyc in _start(self, async)
#     359             self._thread.start()
#     360         else:
# --> 361             self._run()
#     362
#     363     def on_closed(self, resp):
#
# /usr/local/lib/python2.7/dist-packages/tweepy/streaming.pyc in _run(self)
#     261                     self.snooze_time = self.snooze_time_step
#     262                     self.listener.on_connect()
# --> 263                     self._read_loop(resp)
#     264             except (Timeout, ssl.SSLError) as exc:
#     265                 # This is still necessary, as a SSLError can actually be
#
# /usr/local/lib/python2.7/dist-packages/tweepy/streaming.pyc in _read_loop(self, resp)
#     311             length = 0
#     312             while not resp.raw.closed:
# --> 313                 line = buf.read_line().strip()
#     314                 if not line:
#     315                     self.listener.keep_alive()  # keep-alive new lines are expected
#
# /usr/local/lib/python2.7/dist-packages/tweepy/streaming.pyc in read_line(self, sep)
#     177             else:
#     178                 start = len(self._buffer)
# --> 179             self._buffer += self._stream.read(self._chunk_size)
#     180
#     181     def _pop(self, length):
#
# /usr/local/lib/python2.7/dist-packages/requests/packages/urllib3/response.pyc in read(self, amt, decode_content, cache_content)
#     308             else:
#     309                 cache_content = False
# --> 310                 data = self._fp.read(amt)
#     311                 if amt != 0 and not data:  # Platform-specific: Buggy versions of Python.
#     312                     # Close the connection when no data is returned
#
# /usr/lib/python2.7/httplib.pyc in read(self, amt)
#     547
#     548         if self.chunked:
# --> 549             return self._read_chunked(amt)
#     550
#     551         if amt is None:
#
# /usr/lib/python2.7/httplib.pyc in _read_chunked(self, amt)
#     589         while True:
#     590             if chunk_left is None:
# --> 591                 line = self.fp.readline(_MAXLINE + 1)
#     592                 if len(line) > _MAXLINE:
#     593                     raise LineTooLong("chunk size")
#
# /usr/lib/python2.7/socket.pyc in readline(self, size)
#     474             while True:
#     475                 try:
# --> 476                     data = self._sock.recv(self._rbufsize)
#     477                 except error, e:
#     478                     if e.args[0] == EINTR:
#
# /usr/local/lib/python2.7/dist-packages/requests/packages/urllib3/contrib/pyopenssl.pyc in recv(self, *args, **kwargs)
#     205         except OpenSSL.SSL.WantReadError:
#     206             rd, wd, ed = select.select(
# --> 207                 [self.socket], [], [], self.socket.gettimeout())
#     208             if not rd:
#     209                 raise timeout('The read operation timed out')
#
# KeyboardInterrupt:

# %%
client = MongoClient('localhost', 27017)
db = client.newtweetsDB
db.cooltweets.count()
# Out:
# 4807

# %%
import tweepy
from pymongo import MongoClient
import json
import pandas 
import unicodedata

# %%
client = MongoClient('localhost', 27017)
db = client.newtweetsDB
db.cooltweets.count()
# Out:
# 2354

# %%
cursor = db.cooltweets.find() #Where tweets is my collection
tweet_fields = ['text','id']
docs = pandas.DataFrame(list(cursor), columns = tweet_fields)

# %%
doc_complete  = docs['text'].tolist()

# %%
import gensim
from gensim import corpora
from nltk.corpus import stopwords 
from nltk.stem.wordnet import WordNetLemmatizer
import string

stop = set(stopwords.words('english'))
exclude = set(string.punctuation) 
lemma = WordNetLemmatizer()

def clean(doc):
    stop_free = " ".join([i for i in doc.lower().split() if i not in stop])
    punc_free = ''.join(ch for ch in stop_free if ch not in exclude)
    normalized = " ".join(lemma.lemmatize(word) for word in punc_free.split())
    return normalized

doc_clean = [clean(doc).split() for doc in doc_complete]    
#print(doc_clean)

# %%
import re
emoji_pattern = re.compile("["
        u"\U0001F600-\U0001F64F"  # emoticons
        u"\U0001F300-\U0001F5FF"  # symbols & pictographs
        u"\U0001F680-\U0001F6FF"  # transport & map symbols
        u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                           "]+", flags=re.UNICODE)
doc_cleanNew = []
for doc in doc_clean:
    newdoc =  []
    for word in doc:
        #print(word)
        word  =  emoji_pattern.sub(r'', word)
        word =    word.encode('ascii',errors='ignore')
        newdoc.append(word)
        #print(word)
    #print(doc)
    #print(newdoc)
    doc_cleanNew.append(newdoc)
        
print(doc_cleanNew)
# Out:
# [['srithh', 'dont', 'care', 'ysrcp', 'condemning', 'it', 'talking', 'politics', 'here', 'understand', 'kirankonnects01', 'smapbob'], ['hillaryclinton', 'must', 'commend', 'choice', 'clothing', 'it', 'spot', 'on', 'michelleobama', 'too', 'classy', 'hell'], ['', '', '', '', '', '', '', '', '', 'httpstcouexjifyaxf'], ['hillaryclinton', 'hitted', 'park', 'hope', 'win', 'debate'], ['rachitavaid', 'hahahahahaha', 'ive', 'experienced', 'this', 'girishmallya', 'beingdeesee', 'vanityd', 'think', 'need', 'support', 'group', 'people', 'like', 'u', ''], ['karanjohar', 'dont', 'give', 'buddy', 'sab', 'theek', 'hojayega'], ['wishing', 'idol', 'inspiration', 'master', 'mudassar', 'happiehh', 'birthday', 'd', 'mudassarkhan1', 'love', 'load', 'b', 'httpstcozyj7q77epc'], ['', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', 'httpstcokz3xqn8zbu'], ['sas0786', 'waqt', 'sikha', 'deta', 'hai', 'falsfa', 'zindagi', 'ka', 'phir', 'tou', 'naseeb', 'kya', 'lakeer', 'kya', 'aur', 'taqdeer', 'kya'], ['dyk', '1', 'gram', 'poop', 'emoji', 'contains', 'almost', '100', 'billion', 'bacteria', 'wash', 'hand', 'amp', 'rt', 'globalhandwashingday', 'httpstcofhyoij1nqq'], ['shweta', 'varahaswamy', 'temple', 'named', 'varaha', 'third', 'incarnation', 'lord', 'vishnu', 'wild', 'httpstcoqqh59z8ycn'], ['8', 'day', 'shivaay', 'sayeshasaa'], ['one', 'morning', 'httpstcoiltbfvxakj'], ['arvindkejriwal', 'banana', 'republic', 'bjp', 'amp', 'r', 'shame', 'u', 'narendramodi'], ['boot', 'confidante', 'rear', 'slide', 'protector', 'thatssmart', 'companion', 'all', 'httpstco5u3ml7ejen'], ['crore', 'rupee', 'bribe', 'medium', 'run', 'fake', 'trial', 'hindu', 'saint', 'hinduismontarget', 'httpstcoqr4e5qkk6y'], ['', '', '', '', '', '', '', '', '', '', '', ''], ['opportunist444', 'nice', 'juicy', 'increase', 'option', 'number', 'number', 'looking', '8755'], ['virendersehwag', 'happy', 'bithday', 'viru', 'paji'], ['irfhabib', 'katju', 'sb', 'presumed', 'amrood', 'gunda', 'among', 'fruit'], ['', '', '', '', '', '', '', '', '', '', '', '', ''], ['love', 'way', 'men', 'woman', 'live', 'together', 'ritual', 'needed', 'osho'], ['you', 'need', 'find', 'woman', 'who', 'pathetic', 'like', 'you', 'thanks', 'drax', 'guardiansofthegalaxyvol2'], ['8', 'day', 'shivaay', '8', 'day', 'epic', '8', 'day', 'biggest', 'bollywood', 'movie', 'ever', 'ajaydevgn', 'shivaaythefilm'], ['httpstcoashw7c7jgf'], ['take', 'call', 'violence', 'murderyou', 'right', 'mr', 'pinarayi', 'ask', 'party', 'beginning', 'talkas', 'say'], ['', '', '', '', '', '', '', 'httpstcoff5lfqw0ud', 'httpstcobjwr0bdnmp'], ['dishpatani', 'like', 'yourself', 'le', 'youre', 'like', 'anyone', 'else', 'make', 'unique', 'sensation', 'si', 'httpstcolivvtplzsw'], ['almanac', 'gujarat', '', '', '', '', '', '1106', '', '', '', '', '', '', '', 'httpstco5mhz7i4cxb'], ['', '', '', '', '', '', '', 'httpstcoql9m7hsdqf', 'httpstco5bnhmmqcal'], ['fellowship', 'immersive', 'jeff', 'chacko', 'make', 'separating', 'student', 'personal', 'struggle', 'acad', 'httpstcosvw2exrm8n'], ['yarlagaddavrao', 'mean', 'exclusive', 'caste'], ['', '', '2017', '', '', '', '', '', '', '', 'httpstcofu1mu1n8bq'], ['sheikchil', 'credibility', 'still', 'way', 'pedophile', 'allah', 'unlike', 'him', 'real', 'dont', 'care', 'think', 'kindly', 'fuck', 'off'], ['', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', 'hinduismontarget', 'httpstcooajatpmk8r'], ['manali', 'wife', 'httpstcosnmsqmfkth'], ['cluelessforam', 'yeah', 'probably', 'get'], ['buffoon', 'bafoon', 'buffoon', 'httpstcofcnqxqxgg3'], ['', '', '', '', '', '', '', '', '', '', '', '', 'httpstcoglogwwwolw'], ['naampk', 'httpstcon43heip1h0', 'toiindianews'], ['forgiveness', 'attribute', 'strong', 'goodmorning', 'thoughtoftheday', 'httpstcoowbvncgmv7'], ['', '', '', '', '', '', '', 'vc', '', '', '', '', 'shutdownjnu'], ['', '', '', '', '', '', '', '', '', '', '', '', 'httpstcojaxaglhnk2'], ['icicibankcare', 'icicibank', 'httpstcognmlaebo47'], ['every', 'sunset', 'give', 'u', 'one', 'day',  ...

# %%
corpora.Dictionary(doc_cleanNew)
from nltk.corpus import stopwords 
from nltk.stem.wordnet import WordNetLemmatizer
import string
dictionary = corpora.Dictionary(doc_cleanNew)

# %%
doc_term_matrix = [dictionary.doc2bow(doc) for doc in doc_cleanNew]

# %%
Lda = gensim.models.ldamodel.LdaModel
ldamodel = Lda(doc_term_matrix, num_topics=20 , id2word = dictionary, passes=100)
print(ldamodel.print_topics(num_topics= 20, num_words= 10))
# Out:
# [(0, u'0.067* + 0.058*shivaay + 0.053*diwali + 0.047*wali + 0.020*contest + 0.017*day + 0.015*mydiwaligoddess + 0.012*home + 0.012*8 + 0.010*goddess'), (1, u'0.018*thank + 0.011*ke + 0.009*best + 0.008*welcome + 0.008*bro + 0.007*excited + 0.006*amp + 0.006*wish + 0.006*better + 0.006*grade'), (2, u'0.018*r + 0.014*working + 0.011*please + 0.011*many + 0.011*help + 0.011*evening + 0.011*narendramodi + 0.010*guy + 0.010*read + 0.010*mein'), (3, u'0.016*gurmeetramrahim +
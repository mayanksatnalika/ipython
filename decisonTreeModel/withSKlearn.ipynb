# %%
import pandas as pd
import numpy as np
# %matplotlib inline

# %%
data = pd.read_csv('train.csv')
data= data.drop(['Outlet_Identifier'],1)
data= data.drop(['Item_Identifier'],1)
data['Outlet_Size'].fillna('Medium', inplace = True)
#data = data[:15]
min_elements_in_leaf = 3
data2 = pd.DataFrame()
data2['Outlet_Size'] = data['Outlet_Size']
data2['Outlet_Type'] = data['Outlet_Type']
data2['Item_Outlet_Sales'] = data['Item_Outlet_Sales']
data = data2

for col in [ 'Outlet_Size','Outlet_Type']:
    data[col] = data[col].astype('category')

cat_col = []

for col in data:
    if data[col].dtype.name == 'category':
        cat_col.append(col)

result = 'Item_Outlet_Sales'
attrib_value_pair_used = {}

some_avail = {}
for col in data:
    some_avail[col] = 1

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
clf = DecisionTreeClassifier(criterion='mse',max_depth=8, min_samples_split=4, min_samples_leaf=1,max_features = 4 )
clf.fit(data[col], data[result])
# Out:
# /home/fsftn/anaconda2/lib/python2.7/site-packages/sklearn/utils/validation.py:386: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and willraise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-6194ccd09c1d> in <module>()
#       1 clf = DecisionTreeClassifier(criterion='mse',max_depth=8, min_samples_split=4, min_samples_leaf=1,max_features = 4 )
# ----> 2 clf.fit(data[col], data[result])
#
# /home/fsftn/anaconda2/lib/python2.7/site-packages/sklearn/tree/tree.pyc in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     175
#     176         if is_classification:
# --> 177             check_classification_targets(y)
#     178             y = np.copy(y)
# ...

# %%
data
# Out:
#      Outlet_Size        Outlet_Type  Item_Outlet_Sales
# 0         Medium  Supermarket Type1          3735.1380
# 1         Medium  Supermarket Type2           443.4228
# 2         Medium  Supermarket Type1          2097.2700
# 3         Medium      Grocery Store           732.3800
# 4           High  Supermarket Type1           994.7052
# 5         Medium  Supermarket Type2           556.6088
# 6           High  Supermarket Type1           343.5528
# 7         Medium  Supermarket Type3          4022.7636
# 8         Medium  Supermarket Type1          1076.5986
# 9         Medium  Supermarket Type1          4710.5350
# 10        Medium  Supermarket Type1          1516.0266
# 11         Small  Supermarket Type1          2187.1530
# 12        Medium  Supermarket Type1          1589.2646
# 13         Small  Supermarket Type1          2145.2076
# 14          High  Supermarket Type1          1977.4260
# 15         Small  Supermarket Type1          1547.3192
# ...

# %%
clf = DecisionTreeRegressor( )
preds = ['Outlet_Type']
clf.fit(data[preds], data['Item_Outlet_Sales'])
from sklearn import tree
dot_file = tree.export_graphviz(clf.tree_, out_file='tree_d1.dot', feature_names=preds)  #export the tree to .dot file
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-35-5785b0385baf> in <module>()
#       1 clf = DecisionTreeRegressor( )
#       2 preds = ['Outlet_Type']
# ----> 3 clf.fit(data[preds], data['Item_Outlet_Sales'])
#       4 from sklearn import tree
#       5 dot_file = tree.export_graphviz(clf.tree_, out_file='tree_d1.dot', feature_names=preds)  #export the tree to .dot file
#
# /home/fsftn/anaconda2/lib/python2.7/site-packages/sklearn/tree/tree.pyc in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     152         random_state = check_random_state(self.random_state)
#     153         if check_input:
# --> 154             X = check_array(X, dtype=DTYPE, accept_sparse="csc")
#     155             if issparse(X):
#     156                 X.sort_indices()
#
# ...

# %%
from subprocess import check_call
check_call(['dot','-Tpng','tree_d1.dot','-o','OutputFilefinal.png'])
# Out:
# 0

# %%
from bs4 import BeautifulSoup
import urllib2
import pandas as pd
import numpy as np
from dateutil import parser
import os.path
print 'imported files'
# Out:
# imported files

# %%
auc2011 = pd.read_csv('2011_auctions.csv')
pnames= []
players = auc2011['player_name']
for play in players:
    pnames.append(str(play.replace(' ','+')))

# %%
for player_name in pnames:
    try:

        fname = 'score_files/2016b_t20_' + str(player_name) + '.csv'
        print fname
        print player_name
        if (os.path.isfile(fname)):
            print 'file exists'
            continue

        url = 'http://www.bing.com/search?q=cricketarchive.com+player+' + player_name
        print url
        #url  ='http://www.bing.com/search?q=cricketarchive.com+player+ms+dhoni'
        opener = urllib2.build_opener()
        opener.addheaders = [('User-agent', 'Mozilla/5.0')]
        page = opener.open(url)
        soup = BeautifulSoup(page.read(),"html.parser")
        print 'bing sorted'
        #finding list a and t20 urls
        divs = soup.findAll('div',{'class':'b_attribution'})
        for div in divs:
            print 'in div bhai'
            print div.text

            if str(div.text).find('cricketarchive.com/Archive/Players') != -1 or str(div.text).find('cricketarchive.com/Players')!= -1 :


                #__________________MAKE CHANGES SOME HAS ARCHIVE SOME DONT IN URL______________________
                if str(div.text).find('cricketarchive.com/Archive/Players') != -1:
                    types= 1

                else:
                    types = 2






                print div.text
                s1 = div.text
                s2 = 'Players'
                req_str =  s1[s1.index(s2) + len(s2):]
                wrds =  req_str.split('/')
                final_str = wrds[1]+ '/' + wrds[2]
                #print final_str
                if types == 1:
                    listA_url = str('http://cricketarchive.com/Archive/Players/'+final_str+'/List_A_Matches.html')
                    t20_url =   str('http://cricketarchive.com/Archive/Players/'+final_str+'/Twenty20_Matches.html')
                else:

                    listA_url = str('http://cricketarchive.com/Players/'+final_str+'/List_A_Matches.html')
                    t20_url =   str('http://cricketarchive.com/Players/'+final_str+'/Twenty20_Matches.html')

                break
        #urls found out

        listA_runs = []
        t20_runs = []
        listA_overs = []
        t20_overs = []
        listA_wkt = []
        t20_wkt = []
        
        listA_date = []
        t20_date = []


        page = opener.open(listA_url)
        soup = BeautifulSoup(page.read(),"html.parser")
        table = soup.findAll('table')


        rows =  table[0].findAll('tr')
        #print rows[0]
        date_start  = '2015-02-04'
        date_end  = '2016-02-04'

        for row in rows:
            tds  = row.findAll('td')
            #print tds[1].text
            date  = parser.parse(str(tds[1].text))
            if date > parser.parse(date_start) and date < parser.parse(date_end):
                print date.date()
                #listA_date.append(str(date.date()))
                mlink = tds[4].find('a')
                match_link = 'http://cricketarchive.com/' + mlink['href']
                print match_link
                match_page = opener.open(match_link)
                match_soup = BeautifulSoup(match_page.read(),"html.parser")
                #print match_soup

                found  = 0
                tabs = match_soup.findAll('table')


                rows = tabs[2].findAll('tr')
                for row in rows:
                    tds  = row.findAll('td')
                    if len(tds)  < 4:
                        continue
                    if tds[0].find('a'):
                        link_text =  tds[0].find('a')['href']
                        if link_text.find(final_str) != -1:
                            #print tds[2].text
                            #print tds[3].text
                            listA_runs.append(tds[3].text)
                            listA_wkt.append(tds[4].text)
                            listA_overs.append(tds[1].text)
                            found =  1
                            listA_date.append(str(date.date()))
                            break
                if (found== 1 ):
                    continue


                rows = tabs[4].findAll('tr')
                for row in rows:
                    tds  = row.findAll('td')
                    if len(tds) < 4:
                        continue
                    #print tds[0]
                    if tds[0].find('a'):
                        link_text =  tds[0].find('a')['href']
                        if link_text.find(final_str) != -1:
                            listA_runs.append(tds[3].text)
                            listA_wkt.append(tds[4].text)
                            listA_overs.append(tds[1].text)
                            listA_date.append(str(date.date()))
                            break
                            #print tds[2].text
                            #print tds[3].text
        print 'work done for odis, now for t20s'



        page = opener.open(t20_url)
        soup = BeautifulSoup(page.read(),"html.parser")
        table = soup.findAll('table')
        rows =  table[0].findAll('tr')
        #print rows[0]
        date_start  = '2015-02-04'
        date_end  = '2016-02-04'

        for row in rows:
            tds  = row.findAll('td')
            #print tds[1].text
            date  = parser.parse(str(tds[1].text))
            if date > parser.parse(date_start) and date < parser.parse(date_end):
                print date.date()
                #t20_date.append(str(date.date()))
                mlink = tds[4].find('a')
                match_link = 'http://cricketarchive.com/' + mlink['href']
                print match_link
                match_page = opener.open(match_link)
                match_soup = BeautifulSoup(match_page.read(),"html.parser")
                #print match_soup

                found  = 0
                tabs = match_soup.findAll('table')


                rows = tabs[2].findAll('tr')
                for row in rows:
                    tds  = row.findAll('td')
                    if len(tds) < 4:
                        continue
                    #print tds[0]
                    if tds[0].find('a'):
                        link_text =  tds[0].find('a')['href']
                        if link_text.find(final_str) != -1:
                            #print tds[2].text
                            #print tds[3].text
                            t20_runs.append(tds[3].text)
                            t20_wkt.append(tds[4].text)
                            t20_overs.append(tds[1].text)
                            found =  1
                            t20_date.append(str(date.date()))
                            break
                if (found== 1 ):
                    continue


                rows = tabs[4].findAll('tr')
                for row in rows:
                    tds  = row.findAll('td')
                    #print tds[0]
                    if len(tds)<4:
                        continue
                    if tds[0].find('a'):
                        link_text =  tds[0].find('a')['href']
                        if link_text.find(final_str) != -1:
                            t20_runs.append(tds[3].text)
                            t20_wkt.append(tds[4].text)
                            t20_overs.append(tds[1].text)
                            found =  1
                            t20_date.append(str(date.date()))
                            break
                            #print tds[2].text
                            #print tds[3].text
        print 't20s done'

        listA = pd.DataFrame()
        listA['date'] = listA_date
        listA['runs'] = listA_runs
        listA['balls'] = listA_balls
        listA['wkt'] = listA_wkt
        fname = 'score_files/2016b_listA_' + str(player_name) + '.csv'
        listA.to_csv(fname, encoding='utf-8')

        t20 = pd.DataFrame()
        t20['date'] = t20_date
        t20['runs'] = t20_runs
        t20['wkt'] = t20_wkt

        t20['balls'] = t20_balls
        fname = 'score_files/2016b_t20_' + str(player_name) + '.csv'
        t20.to_csv(fname, encoding='utf-8')
        print listA
        print t20
        
    except:
        continue
# Out:
# score_files/2016b_t20_Gautam+Gambhir.csv
# Gautam+Gambhir
# http://www.bing.com/search?q=cricketarchive.com+player+Gautam+Gambhir
# bing sorted
# in div bhai
# cricketarchive.com
# in div bhai
# cricketarchive.com/Archive/Players/7/7736/7736.html
# cricketarchive.com/Archive/Players/7/7736/7736.html
# 2015-12-10
# http://cricketarchive.com//Archive/Scorecards/858/858143.html
# 2015-12-11
# http://cricketarchive.com//Archive/Scorecards/858/858146.html
# 2015-12-13
# http://cricketarchive.com//Archive/Scorecards/858/858149.html
# 2015-12-14
# http://cricketarchive.com//Archive/Scorecards/858/858151.html
# 2015-12-17
# http://cricketarchive.com//Archive/Scorecards/858/858157.html
# 2015-12-18
# http://cricketarchive.com//Archive/Scorecards/858/858162.html
# 2015-12-23
# http://cricketarchive.com//Archive/Scorecards/858/858179.html
# 2015-12-26
# http://cricketarchive.com//Archive/Scorecards/858/858182.html
# 2015-12-28
# http://cricketarchive.com//Archive/Scorecards/858/858184.html
# work done for odis, now for t20s
# 2015-03-24
# http://cricketarchive.com//Archive/Scorecards/684/684637.html
# 2015-03-25
# http://cricketarchive.com//Archive/Scorecards/684/684649.html
# 2015-03-26
# http://cricketarchive.com//Archive/Scorecards/684/684661.html
# 2015-03-27
# http://cricketarchive.com//Archive/Scorecards/684/684671.html
# 2015-04-08
# http://cricketarchive.com//Archive/Scorecards/818/818640.html
# 2015-04-11
# http://cricketarchive.com//Archive/Scorecards/818/818644.html
# 2015-04-18
# http://cricketarchive.com//Archive/Scorecards/818/818654.html
# 2015-04-20
# http://cricketarchive.com//Archive/Scorecards/818/818657.html
# 2015-04-22
# http://cricketarchive.com//Archive/Scorecards/818/818659.html
# 2015-04-28
# http://cricketarchive.com//Archive/Scorecards/818/818668.html
# 2015-04-30
# http://cricketarchive.com//Archive/Scorecards/818/818649.html
# 2015-05-02
# http://cricketarchive.com//Archive/Scorecards/818/818673.html
# 2015-05-04
# http://cricketarchive.com//Archive/Scorecards/818/818678.html
# 2015-05-07
# http://cricketarchive.com//Archive/Scorecards/818/818670.html
# 2015-05-09
# http://cricketarchive.com//Archive/Scorecards/818/818683.html
# 2015-05-14
# http://cricketarchive.com//Archive/Scorecards/818/818690.html
# 2015-05-16
# http://cricketarchive.com//Archive/Scorecards/818/818693.html
# 2016-01-02
# http://cricketarchive.com//Archive/Scorecards/858/858232.html
# 2016-01-03
# http://cricketarchive.com//Archive/Scorecards/858/858235.html
# 2016-01-04
# http://cricketarchive.com//Archive/Scorecards/858/858238.html
# 2016-01-06
# http://cricketarchive.com//Archive/Scorecards/858/858240.html
# 2016-01-09
# http://cricketarchive.com//Archive/Scorecards/858/858246.html
# 2016-01-10
# http://cricketarchive.com//Archive/Scorecards/858/858251.html
# 2016-01-15
# http://cricketarchive.com//Archive/Scorecards/858/858273.html
# 2016-01-16
# http://cricketarchive.com//Archive/Scorecards/858/858276.html
# 2016-01-18
# http://cricketarchive.com//Archive/Scorecards/858/858278.html
# t20s done
# score_files/2016b_t20_Yusuf+Pathan.csv
# Yusuf+Pathan
# http://www.bing.com/search?q=cricketarchive.com+player+Yusuf+Pathan
# bing sorted
# in div bhai
# cricketarchive.com
# in div bhai
# www.cricketarchive.com/Archive/Players/15/15222/15222.html
# www.cricketarchive.com/Archive/Players/15/15222/15222.html
